# %% [markdown]
# Deep Learning
# =============
#
# Assignment 5
# ------------
#
# The goal of this assignment is to train a Word2Vec skip-gram model over [Text8](http://mattmahoney.net/dc/textdata) data.

# %%
# These are all the modules we'll be using later. Make sure you can import them
# before proceeding further.
# %matplotlib inline
from __future__ import print_function
import collections
import math
import numpy as np
import os
import random
import tensorflow as tf
import zipfile
from matplotlib import pylab
from six.moves import range
from six.moves.urllib.request import urlretrieve
from sklearn.manifold import TSNE
import datetime
from itertools import compress

# %% [markdown]
# Download the data from the source website if necessary.

# %%
url = 'http://mattmahoney.net/dc/'

def maybe_download(filename, expected_bytes):
    """Download a file if not present, and make sure it's the right size."""
    if not os.path.exists(filename):
        filename, _ = urlretrieve(url + filename, filename)
    statinfo = os.stat(filename)
    if statinfo.st_size == expected_bytes:
        print('Found and verified %s' % filename)
    else:
        print(statinfo.st_size)
        raise Exception(
            'Failed to verify ' + filename + '. Can you get to it with a browser?')
    return filename

filename = maybe_download('text8.zip', 31344016)
# Out:
# Found and verified text8.zip

# %% [markdown]
# Read the data into a string.

# %%
def read_data(filename):
    """Extract the first file enclosed in a zip file as a list of words"""
    with zipfile.ZipFile(filename) as f:
        data = tf.compat.as_str(f.read(f.namelist()[0])).split()
    return data
    
words = read_data(filename)
print('Data size %d' % len(words))
# Out:
# Data size 17005207

# %% [markdown]
# Build the dictionary and replace rare words with UNK token.

# %%
vocabulary_size = 50000

def build_dataset(words):
    count = [['UNK', -1]]
    count.extend(collections.Counter(words).most_common(vocabulary_size - 1))
    dictionary = dict()
    for word, _ in count:
        dictionary[word] = len(dictionary)
    data = list()
    unk_count = 0
    for word in words:
        if word in dictionary:
            index = dictionary[word]
        else:
            index = 0    # dictionary['UNK']
            unk_count = unk_count + 1
        data.append(index)
    count[0][1] = unk_count
    reverse_dictionary = dict(zip(dictionary.values(), dictionary.keys())) 
    return data, count, dictionary, reverse_dictionary

data, count, dictionary, reverse_dictionary = build_dataset(words)
print('Most common words (+UNK)', count[:5])
print('Sample data', data[:10])
 # Hint to reduce memory.
# Out:
# Most common words (+UNK) [['UNK', 418391], ('the', 1061396), ('of', 593677), ('and', 416629), ('one', 411764)]
# Sample data [5237, 3084, 12, 6, 195, 2, 3136, 46, 59, 156]

# %%
print ('Dict:', dictionary['UNK'])
print ('Reverse dict:', reverse_dictionary[0])
print ('Counter:', count[dictionary['UNK']])
print ('Data:', data[0])
print ('Words:', words[:10])
# Out:
# Dict: 0
# Reverse dict: UNK
# Counter: ['UNK', 418391]
# Data: 5237
# Words: ['anarchism', 'originated', 'as', 'a', 'term', 'of', 'abuse', 'first', 'used', 'against']

# %%
del words

# %% [markdown]
# Function to generate a training batch for the skip-gram model.

# %% [markdown]
# # Skip-gram model

# %%
data_index = 0

def generate_batch(batch_size, num_skips, skip_window):
    global data_index
    assert batch_size % num_skips == 0
    assert num_skips <= 2 * skip_window
    batch = np.ndarray(shape=(batch_size), dtype=np.int32)
    labels = np.ndarray(shape=(batch_size, 1), dtype=np.int32)
    span = 2 * skip_window + 1 # [ skip_window target skip_window ]
    buffer = collections.deque(maxlen=span)
    for _ in range(span):
        buffer.append(data[data_index])
        data_index = (data_index + 1) % len(data)
    for i in range(batch_size // num_skips):
        target = skip_window    # target label at the center of the buffer
        targets_to_avoid = [ skip_window ]
        for j in range(num_skips):
            while target in targets_to_avoid:
                target = random.randint(0, span - 1)
            targets_to_avoid.append(target)
            batch[i * num_skips + j] = buffer[skip_window]
            labels[i * num_skips + j, 0] = buffer[target]
        buffer.append(data[data_index])
        data_index = (data_index + 1) % len(data)
    return batch, labels

print('data:', [reverse_dictionary[di] for di in data[:8]])

for num_skips, skip_window in [(2, 1), (4, 2), (2, 2)]:
        data_index = 0
        batch, labels = generate_batch(batch_size=8, num_skips=num_skips, skip_window=skip_window)
        print('\nwith num_skips = %d and skip_window = %d:' % (num_skips, skip_window))
        print('        batch:', [reverse_dictionary[bi] for bi in batch])
        print('        labels:', [reverse_dictionary[li] for li in labels.reshape(8)])
# Out:
# data: ['anarchism', 'originated', 'as', 'a', 'term', 'of', 'abuse', 'first']
#
# with num_skips = 2 and skip_window = 1:
#         batch: ['originated', 'originated', 'as', 'as', 'a', 'a', 'term', 'term']
#         labels: ['anarchism', 'as', 'a', 'originated', 'term', 'as', 'of', 'a']
#
# with num_skips = 4 and skip_window = 2:
#         batch: ['as', 'as', 'as', 'as', 'a', 'a', 'a', 'a']
#         labels: ['term', 'a', 'anarchism', 'originated', 'originated', 'of', 'as', 'term']
#
# with num_skips = 2 and skip_window = 2:
#         batch: ['as', 'as', 'a', 'a', 'term', 'term', 'of', 'of']
#         labels: ['term', 'originated', 'term', 'as', 'as', 'abuse', 'first', 'a']

# %%
batch_size = 128
embedding_size = 128 # Dimension of the embedding vector.
skip_window = 1 # How many words to consider left and right.
num_skips = 2 # How many times to reuse an input to generate a label.
# We pick a random validation set to sample nearest neighbors. here we limit the
# validation samples to the words that have a low numeric ID, which by
# construction are also the most frequent. 
valid_size = 16 # Random set of words to evaluate similarity on.
valid_window = 100 # Only pick dev samples in the head of the distribution.
valid_examples = np.array(random.sample(range(valid_window), valid_size))
num_sampled = 64 # Number of negative examples to sample.

graph = tf.Graph()

with graph.as_default(), tf.device('/cpu:0'):
    # Input data.
    train_dataset = tf.placeholder(tf.int32, shape=[batch_size])
    train_labels = tf.placeholder(tf.int32, shape=[batch_size, 1])
    valid_dataset = tf.constant(valid_examples, dtype=tf.int32)
    
    # Variables.
    embeddings = tf.Variable(tf.random_uniform([vocabulary_size, embedding_size], -1.0, 1.0))
    softmax_weights = tf.Variable(tf.truncated_normal([vocabulary_size, embedding_size],
                                                      stddev=1.0 / math.sqrt(embedding_size)))
    softmax_biases = tf.Variable(tf.zeros([vocabulary_size]))
    
    # Model.
    # Look up embeddings for inputs.
    embed = tf.nn.embedding_lookup(embeddings, train_dataset)
    # Compute the softmax loss, using a sample of the negative labels each time.
    loss = tf.reduce_mean(tf.nn.sampled_softmax_loss(weights=softmax_weights, 
                                                     biases=softmax_biases, 
                                                     inputs=embed,
                                                     labels=train_labels, 
                                                     num_sampled=num_sampled, 
                                                     num_classes=vocabulary_size))

    # Optimizer.
    # Note: The optimizer will optimize the softmax_weights AND the embeddings.
    # This is because the embeddings are defined as a variable quantity and the
    # optimizer's `minimize` method will by default modify all variable quantities 
    # that contribute to the tensor it is passed.
    # See docs on `tf.train.Optimizer.minimize()` for more details.
    optimizer = tf.train.AdagradOptimizer(1.0).minimize(loss)
    
    # Compute the similarity between minibatch examples and all embeddings.
    # We use the cosine distance:
    norm = tf.sqrt(tf.reduce_sum(tf.square(embeddings), 1, keep_dims=True))
    normalized_embeddings = embeddings / norm
    valid_embeddings = tf.nn.embedding_lookup(normalized_embeddings, valid_dataset)
    similarity = tf.matmul(valid_embeddings, tf.transpose(normalized_embeddings))

# %%
num_steps = 100001
t0 = datetime.datetime.now()

with tf.Session(graph=graph) as session:
    tf.global_variables_initializer().run()
    print('Initialized')
    average_loss = 0
    for step in range(num_steps):
        batch_data, batch_labels = generate_batch(batch_size, num_skips, skip_window)
        feed_dict = {train_dataset : batch_data, train_labels : batch_labels}
        _, l = session.run([optimizer, loss], feed_dict=feed_dict)
        average_loss += l
        if step % 2000 == 0:
            if step > 0:
                average_loss = average_loss / 2000
            # The average loss is an estimate of the loss over the last 2000 batches.
            print('Average loss at step %d: %f' % (step, average_loss))
            average_loss = 0
        # note that this is expensive (~20% slowdown if computed every 500 steps)
        if step % 10000 == 0:
            sim = similarity.eval()
            for i in range(valid_size):
                valid_word = reverse_dictionary[valid_examples[i]]
                top_k = 8 # number of nearest neighbors
                nearest = (-sim[i, :]).argsort()[1:top_k+1]
                log = 'Nearest to %s:' % valid_word
                for k in range(top_k):
                    close_word = reverse_dictionary[nearest[k]]
                    log = '%s %s,' % (log, close_word)
                print(log)
    final_embeddings = normalized_embeddings.eval()
# Out:
# Initialized
# Average loss at step 0: 8.271820
# Nearest to system: adnan, canc, analgesia, anime, figurines, acker, epicycle, linnaean,
# Nearest to that: trendy, epiphany, distribute, palermo, disasters, discovery, paralleling, traverse,
# Nearest to american: deterioration, borrowing, trafford, ge, offshore, silverberg, steroid, hydrate,
# Nearest to new: wrong, bottlenose, hain, whiz, pisano, grands, athabasca, zeus,
# Nearest to this: bourke, thyroxine, cameroun, responses, incidence, gonzales, catania, monuments,
# Nearest to as: cabrera, acetaminophen, cain, centres, vav, heisei, distinctions, pools,
# Nearest to eight: nadu, sciences, overcrowded, hosting, dispel, opiates, headquartered, specialist,
# Nearest to see: inciting, identifiable, doth, cs, cinematography, organised, laredo, phrygian,
# Nearest to in: mogadishu, vitality, keeper, paso, jose, yasser, synchronisation, lawful,
# Nearest to into: slays, michelangelo, brazzaville, salut, cabinets, fano, lfar, pei,
# Nearest to zero: happenings, countered, starfish, puppeteer, excludes, arbitrage, mound, yetzirah,
# Nearest to two: emoticons, fema, ontario, berlin, transsexualism, observance, insecurity, fein,
# Nearest to is: bourbaki, fleshed, secant, pasha, measuring, bunge, centralisation, interceptor,
# Nearest to if: masjid, stoke, citrate, purpurea, recommends, usurp, depends, montessori,
# Nearest to four: labeling, intrigued, alb, chieftain, estuary, prevention, arndt, sil,
# Nearest to s: sza, cv, bmp, jun, stripped, screen, coat, narrowing,
# Average loss at step 2000: 4.369614
# Average loss at step 4000: 3.865003
# Average loss at step 6000: 3.791502
# Average loss at step 8000: 3.688988
# Average loss at step 10000: 3.616024
# Nearest to system: adnan, anime, canc, cays, epicycle, bestow, analgesia, yonkers,
# Nearest to that: which, recreated, it, she, this, limestones, castrato, took,
# Nearest to american: and, ccc, borrowing, abc, ge, trafford, dangling, hatton,
# Nearest to new: wrong, bamberger, caving, umi, murmur, athabasca, treat, isa,
# Nearest to this: it, the, which, a, his, some, gonzales, that,
# Nearest to as: by, mercury, cabrera, hillel, elvira, nouveaux, blower, turntables,
# Nearest to eight: nine, six, four, five, seven, three, zero, two,
# Nearest to see: inciting, cs, doth, cinematography, cpk, laredo, mprp, georgians,
# Nearest to in: of, on, at, with, from, keeper, between, and,
# Nearest to into: within, salut, cordwainer, evaporation, rink, in, rapture, by,
# Nearest to zero: five, six, seven, nine, eight, four, three, two,
# Nearest to two: five, four, three, six, eight, seven, zero, nine,
# Nearest to is: was, are, has, but, by, simplicius, factually, were,
# Nearest to if: immense, masjid, scoreboard, sails, alteration, sucked, daring, banker,
# Nearest to four: six, eight, five, three, seven, nine, two, zero,
# Nearest to s: his, obligated, or, and, sigma, immunities, dw, blasts,
# Average loss at step 12000: 3.608654
# Average loss at step 14000: 3.567840
# Average loss at step 16000: 3.404584
# Average loss at step 18000: 3.462880
# Average loss at step 20000: 3.541703
# Nearest to system: adnan, anime, inhospitable, canc, cays, epicycle, analgesia, robo,
# Nearest to that: which, but, what, recreated, same, disarmament, juggalo, however,
# Nearest to american: french, trafford, borrowing, hermann, kohen, ineffectual, english, and,
# Nearest to new: isa, wrong, bamberger, warming, flavour, conscious, naturalis, edwin,
# Nearest to this: it, which, the, some, a, his, its, mashal,
# Nearest to as: mercury, cabrera, without, turntables, brennan, subtypes, atheromatous, hadn,
# Nearest to eight: nine, six, seven, five, four, three, zero, two,
# Nearest to see: inciting, cs, cpk, doth, residential, jake, emphases, but,
# Nearest to in: at, on, with, from, during, undergone, between, today,
# Nearest to into: by, within, rapture, salut, from, cabinets, disabled, cordwainer,
# Nearest to zero: five, six, four, seven, nine, eight, three, two,
# Nearest to two: three, five, four, six, one, seven, eight, zero,
# Nearest to is: was, has, are, be, but, were, barak, myr,
# Nearest to if: where, immense, covertly, when, pacifists, watered, but, though,
# Nearest to four: three, six, eight, five, seven, two, nine, zero,
# Nearest to s: semester, disk, satie, strengthening, endpoints, cord, corrupts, sewage,
# Average loss at step 22000: 3.502003
# Average loss at step 24000: 3.489120
# Average loss at step 26000: 3.484275
# Average loss at step 28000: 3.477264
# Average loss at step 30000: 3.504322
# Nearest to system: inhospitable, adnan, anime, robo, catches, process, disappears, arcologies,
# Nearest to that: which, this, what, worry, but, cutbacks, however, disarmament,
# Nearest to american: french, english, british, ineffectual, german, kohen, italian, shapeshifting,
# Nearest to new: warming, naturalis, isa, kansai, court, edwin, conscious, mazarin,
# Nearest to this: which, it, that, there, any, some, mctell, his,
# Nearest to as: cabrera, without, subtypes, when, by, mercury, better, woolf,
# Nearest to eight: nine, seven, six, five, four, three, zero, two,
# Nearest to see: residential, quarries, cpk, inciting, jacobs, doth, soleil, jake,
# Nearest to in: of, on, at, within, during, and, by, from,
# Nearest to into: from, within, through, rapture, under, salut, on, disabled,
# Nearest to zero: five, seven, six, four, eight, three, nine, two,
# Nearest to two: three, four, five, one, seven, six, eight, nine,
# Nearest to is: was, has, are, were, be, simplicius, tla, spousal,
# Nearest to if: when, where, though, immense, pacifists, silicone, alteration, good,
# Nearest to four: five, six, three, seven, eight, two, nine, zero,
# Nearest to s: his, semester, pillow, obligated, quantifying, wal, cucumber, strengthening,
# Average loss at step 32000: 3.501907
# Average loss at step 34000: 3.493056
# Average loss at step 36000: 3.456617
# Average loss at step 38000: 3.304677
# Average loss at step 40000: 3.428129
# Nearest to system: inhospitable, adnan, systems, arcologies, assertive, anime, process, undetected,
# Nearest to that: which, what, this, recreated, where, who, because, also,
# Nearest to american: british, french, australian, english, ineffectual, hermann, lutz, german,
# Nearest to new: warming, flavour, naturalis, jordanian, conscious, isa, court, spurt,
# Nearest to this: which, it, that, the, another, thunderball, there, dg,
# Nearest to as: subtypes, elvira, inv, mile, when, hadn, mercury, turntables,
# Nearest to eight: seven, nine, six, five, four, three, zero, two,
# Nearest to see: residential, quarries, soleil, ezekiel, cpk, references, can, but,
# Nearest to in: of, for, during, on, from, seperate, at, disqualification,
# Nearest to into: from, through, within, salut, over, affluent, by, cabinets,
# Nearest to zero: five, seven, nine, eight, six, four, three, two,
# Nearest to two: three, four, five, seven, six, eight, one, nine,
# Nearest to is: was, are, has, be, superficial, hays, if, represents,
# Nearest to if: when, where, though, is, t, yd, persuasion, pacifists,
# Nearest to four: six, five, seven, three, eight, two, nine, zero,
# Nearest to s: rth, his, semester, zonker, stills, popeye, slurred, quantifying,
# Average loss at step 42000: 3.439648
# Average loss at step 44000: 3.451871
# Average loss at step 46000: 3.449500
# Average loss at step 48000: 3.364368
# Average loss at step 50000: 3.382650
# Nearest to system: systems, inhospitable, adnan, process, robo, arcologies, encke, assertive,
# Nearest to that: which, however, this, but, disarmament, castrato, what, who,
# Nearest to american: french, australian, british, african, lutz, extra, brazilian, russian,
# Nearest to new: naturalis, jordanian, conscious, flavour, mazarin, warming, codepages, echo,
# Nearest to this: which, it, the, that, some, he, lager, his,
# Nearest to as: by, mercury, cabrera, nouveaux, subtypes, inv, montoya, bulletins,
# Nearest to eight: six, nine, seven, four, five, three, zero, two,
# Nearest to see: quarries, soleil, include, residential, pharmaceuticals, references, restraining, jacobs,
# Nearest to in: during, within, on, of, since, throughout, from, yasser,
# Nearest to into: from, through, within, under, searing, over, down, rapture,
# Nearest to zero: five, seven, eight, six, nine, four, three, two,
# Nearest to two: three, four, one, five, six, seven, eight, zero,
# Nearest to is: was, has, are, be, became, although, hays, represents,
# Nearest to if: when, though, where, although, cleartype, could, wish, is,
# Nearest to four: six, eight, five, three, seven, nine, two, zero,
# Nearest to s: his, rth, while, immunities, whose, and, unambiguous, stockade,
# Average loss at step 52000: 3.436828
# Average loss at step 54000: 3.424556
# Average loss at step 56000: 3.439318
# Average loss at step 58000: 3.399093
# Average loss at step 60000: 3.392546
# Nearest to system: systems, inhospitable, adnan, process, robo, canto, chin, encke,
# Nearest to that: which, however, this, what, it, juggalo, there, castrato,
# Nearest to american: british, french, australian, african, russian, brazilian, lutz, embody,
# Nearest to new: jordanian, warming, naturalis, conscious, abstention, isa, repudiating, kansai,
# Nearest to this: it, which, that, there, lager, the, some, stress,
# Nearest to as: cabrera, by, pristine, bulletins, pattie, when, better, sweets,
# Nearest to eight: six, nine, seven, four, five, three, zero, one,
# Nearest to see: but, quarries, include, references, list, residential, pharmaceuticals, malware,
# Nearest to in: within, during, of, including, among, since, throughout, disqualification,
# Nearest to into: within, through, from, over, disabled, salut, rapture, searing,
# Nearest to zero: five, seven, four, eight, six, nine, three, two,
# Nearest to two: three, four, five, six, seven, one, eight, zero,
# Nearest to is: was, are, has, be, although, remains, became, does,
# Nearest to if: when, where, though, although, because, could, since, cannot,
# Nearest to four: six, five, seven, eight, three, nine, two, zero,
# Nearest to s: whose, stockade, slurred, corrupts, espousing, muir, centralize, guggenheim,
# Average loss at step 62000: 3.239648
# Average loss at step 64000: 3.255653
# Average loss at step 66000: 3.404943
# Average loss at step 68000: 3.390425
# Average loss at step 70000: 3.362339
# Nearest to system: systems, inhospitable, adnan, process, robo, arcologies, program, itching,
# Nearest to that: which, however, what, this, but, juggalo, typically, cultivating,
# Nearest to american: british, australian, brazilian, african, italian, french, embody, extra,
# Nearest to new: warming, jordanian, local, naturalis, repudiating, malthus, kansai, heraclius,
# Nearest to this: which, it, the, that, some, another, any, these,
# Nearest to as: when, cabrera, bulletins, is, nouveaux, exposures, aulus, mercury,
# Nearest to eight: nine, six, seven, four, five, three, zero, two,
# Nearest to see: but, list, quarries, include, references, malware, and, refers,
# Nearest to in: within, during, among, on, until, throughout, for, including,
# Nearest to into: from, through, within, disabled, chel, connell, salut, over,
# Nearest to zero: five, four, six, eight, seven, nine, three, two,
# Nearest to two: three, four, six, one, five, seven, eight, zero,
# Nearest to is: was, are, has, be, hays, although, involves, contains,
# Nearest to if: when, where, though, although, before, while, however, cleartype,
# Nearest to four: six, five, three, seven, eight, zero, two, nine,
# Nearest to s: whose, stockade, isbn, scalpel, rth, pillow, semester, grady,
# Average loss at step 72000: 3.376323
# Average loss at step 74000: 3.344171
# Average loss at step 76000: 3.314265
# Average loss at step 78000: 3.354244
# Average loss at step 80000: 3.377176
# Nearest to system: systems, inhospitable, adnan, process, arcologies, chin, itching, robo,
# Nearest to that: which, however, this, where, aux, what, lager, juggalo,
# Nearest to american: british, australian, italian, french, canadian, european, brazilian, african,
# Nearest to new: warming, repudiating, naturalis, jordanian, excludes, kansai, yankees, approximating,
# Nearest to this: which, the, it, that, lager, penh, what, another,
# Nearest to as: exposures, noumenon, berkley, kilocalories, elvira, colloquial, when, horizons,
# Nearest to eight: nine, six, seven, five, four, three, zero, two,
# Nearest to see: include, but, references, according, list, autonomic, refers, pharmaceuticals,
# Nearest to in: within, during, on, until, throughout, under, through, of,
# Nearest to into: through, within, from, disabled, over, chel, salut, oberlin,
# Nearest to zero: five, six, seven, eight, four, nine, three, two,
# Nearest to two: three, four, five, six, seven, one, eight, zero,
# Nearest to is: was, has, are, became, be, involves, does, although,
# Nearest to if: when, where, though, before, although, since, because, whether,
# Nearest to four: five, six, three, eight, seven, nine, two, zero,
# Nearest to s: semester, isbn, sewage, chestnuts, plotinus, pillow, zonker, mindat,
# Average loss at step 82000: 3.407255
# Average loss at step 84000: 3.410841
# Average loss at step 86000: 3.392491
# Average loss at step 88000: 3.353674
# Average loss at step 90000: 3.365655
# Nearest to system: systems, inhospitable, process, adnan, arcologies, robo, chin, metastability,
# Nearest to that: which, however, what, recreated, but, aux, marxian, where,
# Nearest to american: british, italian, australian, african, french, european, canadian, lutz,
# Nearest to new: jordanian, naturalis, particular, pueblo, repudiating, background, warming, approximating,
# Nearest to this: which, it, the, any, another, some, penh, wreckin,
# Nearest to as: bulletins, sandman, subtypes, rajendra, cabrera, pedestrian, repeating, clanking,
# Nearest to eight: seven, nine, six, five, four, three, zero, two,
# Nearest to see: list, references, pharmaceuticals, soleil, include, but, refer, quarries,
# Nearest to in: within, during, under, at, of, greenman, on, around,
# Nearest to into: through, from, within, salut, disabled, down, under, chel,
# Nearest to zero: five, seven, six, eight, four, nine, three, two,
# Nearest to two: three, four, five, seven, six, eight, one, zero,
# Nearest to is: was, has, are, although, involves, became, makes, represents,
# Nearest to if: when, where, though, since, before, then, after, although,
# Nearest to four: seven, five, three, six, eight, two, nine, zero,
# Nearest to s: espousing, chestnuts, his, lou, stockade, pillow, your, isbn,
# Average loss at step 92000: 3.397590
# Average loss at step 94000: 3.250708
# Average loss at step 96000: 3.358671
# Average loss at step 98000: 3.241717
# Average loss at step 100000: 3.361385
# Nearest to system: systems, inhospitable, process, adnan, robo, metastability, arcologies, chin,
# Nearest to that: which, however, what, this, bumpy, aux, who, where,
# Nearest to american: british, canadian, italian, french, australian, mysore, ineffectual, paternalistic,
# Nearest to new: jordanian, pueblo, approximating, naturalis, particular, old, different, background,
# Nearest to this: which, it, another, the, that, some, what, penh,
# Nearest to as: exposures, bulletins, rajendra, subtypes, cabrera, andalusian, pedestrian, when,
# Nearest to eight: nine, seven, four, six, five, three, zero, two,
# Nearest to see: references, pharmaceuticals, list, links, floyd, dimers, refers, soleil,
# Nearest to in: within, during, throughout, on, from, among, near, until,
# Nearest to into: through, within, from, disabled, salut, searing, across, down,
# Nearest to zero: five, four, seven, six, eight, nine, two, three,
# Nearest to two: three, four, five, six, seven, eight, one, zero,
# Nearest to is: was, became, has, be, seems, are, refers, liaisons,
# Nearest to if: when, though, where, because, before, then, although, while,
# Nearest to four: five, seven, six, eight, three, two, nine, zero,
# Nearest to s: his, whose, your, chestnuts, zebulun, pore, stills, my,

# %%
num_points = 400

tsne = TSNE(perplexity=30, n_components=2, init='pca', n_iter=5000)
two_d_embeddings = tsne.fit_transform(final_embeddings[1:num_points+1, :])

# %%
def plot(embeddings, labels):
    assert embeddings.shape[0] >= len(labels), 'More labels than embeddings'
    pylab.figure(figsize=(15,15))    # in inches
    for i, label in enumerate(labels):
        x, y = embeddings[i,:]
        pylab.scatter(x, y)
        pylab.annotate(label, xy=(x, y), xytext=(5, 2), textcoords='offset points',
                                     ha='right', va='bottom')
    pylab.show()

words = [reverse_dictionary[i] for i in range(1, num_points+1)]
plot(two_d_embeddings, words)

# %% [markdown]
# ---
#
# Problem
# -------
#
# An alternative to skip-gram is another Word2Vec model called [CBOW](http://arxiv.org/abs/1301.3781) (Continuous Bag of Words). In the CBOW model, instead of predicting a context word from a word vector, you predict a word from the sum of all the word vectors in its context. Implement and evaluate a CBOW model trained on the text8 dataset.
#
# ---

# %% [markdown]
# # CBOW model

# %%
data_index = 0

def generate_batch_CBOW(batch_size, num_skips, skip_window):
    global data_index
    assert batch_size % num_skips == 0
    assert num_skips <= 2 * skip_window
    batch = np.ndarray(shape=(batch_size, num_skips), dtype=np.int32)
    labels = np.ndarray(shape=(batch_size, 1), dtype=np.int32)
    span = 2 * skip_window + 1 # [ skip_window target skip_window ]
    buffer = collections.deque(maxlen=span)
    for _ in range(span):
        buffer.append(data[data_index])
        data_index = (data_index + 1) % len(data)
    for i in range(batch_size):
        mask = [1 - (ind == skip_window) for ind in range(span)]
        batch[i, :] = list(compress(buffer, mask)) # all surrounding words
        labels[i, 0] = buffer[skip_window] # the word at the center 
        buffer.append(data[data_index])
        data_index = (data_index + 1) % len(data)
    return batch, labels

print('data:', [reverse_dictionary[di] for di in data[:8]])

for num_skips, skip_window in [(4, 2), (2, 1)]:
        data_index = 0
        batch, labels = generate_batch_CBOW(batch_size=8, num_skips=num_skips, skip_window=skip_window)
        print('\nwith num_skips = %d and skip_window = %d:' % (num_skips, skip_window))
        print('        batch:', [[reverse_dictionary[bi_i] for bi_i in bi] for bi in batch])
        print('        labels:', [reverse_dictionary[li] for li in labels.reshape(8)])
# Out:
# data: ['anarchism', 'originated', 'as', 'a', 'term', 'of', 'abuse', 'first']
#
# with num_skips = 4 and skip_window = 2:
#         batch: [['anarchism', 'originated', 'a', 'term'], ['originated', 'as', 'term', 'of'], ['as', 'a', 'of', 'abuse'], ['a', 'term', 'abuse', 'first'], ['term', 'of', 'first', 'used'], ['of', 'abuse', 'used', 'against'], ['abuse', 'first', 'against', 'early'], ['first', 'used', 'early', 'working']]
#         labels: ['as', 'a', 'term', 'of', 'abuse', 'first', 'used', 'against']
#
# with num_skips = 2 and skip_window = 1:
#         batch: [['anarchism', 'as'], ['originated', 'a'], ['as', 'term'], ['a', 'of'], ['term', 'abuse'], ['of', 'first'], ['abuse', 'used'], ['first', 'against']]
#         labels: ['originated', 'as', 'a', 'term', 'of', 'abuse', 'first', 'used']

# %%
batch_size = 128
embedding_size = 128 # Dimension of the embedding vector.
skip_window = 1 # How many words to consider left and right.
num_skips = 2 # How many times to reuse an input to generate a label.
# We pick a random validation set to sample nearest neighbors. here we limit the
# validation samples to the words that have a low numeric ID, which by
# construction are also the most frequent. 
valid_size = 16 # Random set of words to evaluate similarity on.
valid_window = 100 # Only pick dev samples in the head of the distribution.
valid_examples = np.array(random.sample(range(valid_window), valid_size))
num_sampled = 64 # Number of negative examples to sample.

graph = tf.Graph()

with graph.as_default(), tf.device('/cpu:0'):
    # Input data.
    train_dataset = tf.placeholder(tf.int32, shape=[batch_size, num_skips])
    train_labels = tf.placeholder(tf.int32, shape=[batch_size, 1])
    valid_dataset = tf.constant(valid_examples, dtype=tf.int32)
    
    # Variables.
    embeddings = tf.Variable(tf.random_uniform([vocabulary_size, embedding_size], -1.0, 1.0))
    softmax_weights = tf.Variable(tf.truncated_normal([vocabulary_size, embedding_size],
                                                      stddev=1.0 / math.sqrt(embedding_size)))
    softmax_biases = tf.Variable(tf.zeros([vocabulary_size]))
    
    # Model.
    # Look up embeddings for inputs.
    embed = tf.zeros([batch_size, embedding_size])
    for j in range(num_skips):
        embed += tf.nn.embedding_lookup(embeddings, train_dataset[:, j])
    # Compute the softmax loss, using a sample of the negative labels each time.
    loss = tf.reduce_mean(tf.nn.sampled_softmax_loss(weights=softmax_weights, 
                                                     biases=softmax_biases, 
                                                     inputs=embed,
                                                     labels=train_labels, 
                                                     num_sampled=num_sampled, 
                                                     num_classes=vocabulary_size))

    # Optimizer.
    # Note: The optimizer will optimize the softmax_weights AND the embeddings.
    # This is because the embeddings are defined as a variable quantity and the
    # optimizer's `minimize` method will by default modify all variable quantities 
    # that contribute to the tensor it is passed.
    # See docs on `tf.train.Optimizer.minimize()` for more details.
    optimizer = tf.train.AdagradOptimizer(1.0).minimize(loss)
    
    # Compute the similarity between minibatch examples and all embeddings.
    # We use the cosine distance:
    norm = tf.sqrt(tf.reduce_sum(tf.square(embeddings), 1, keep_dims=True))
    normalized_embeddings = embeddings / norm
    valid_embeddings = tf.nn.embedding_lookup(normalized_embeddings, valid_dataset)
    similarity = tf.matmul(valid_embeddings, tf.transpose(normalized_embeddings))

# %%
num_steps = 100001
t0 = datetime.datetime.now()

with tf.Session(graph=graph) as session:
    tf.global_variables_initializer().run()
    print('Initialized')
    average_loss = 0
    for step in range(num_steps):
        batch_data, batch_labels = generate_batch_CBOW(batch_size, num_skips, skip_window)
        feed_dict = {train_dataset : batch_data, train_labels : batch_labels}
        _, l = session.run([optimizer, loss], feed_dict=feed_dict)
        average_loss += l
        if step % 2000 == 0:
            if step > 0:
                average_loss = average_loss / 2000
            # The average loss is an estimate of the loss over the last 2000 batches.
            print('Average loss at step %d: %f' % (step, average_loss))
            average_loss = 0
        # note that this is expensive (~20% slowdown if computed every 500 steps)
        if step % 10000 == 0:
            sim = similarity.eval()
            for i in range(valid_size):
                valid_word = reverse_dictionary[valid_examples[i]]
                top_k = 8 # number of nearest neighbors
                nearest = (-sim[i, :]).argsort()[1:top_k+1]
                log = 'Nearest to %s:' % valid_word
                for k in range(top_k):
                    close_word = reverse_dictionary[nearest[k]]
                    log = '%s %s,' % (log, close_word)
                print(log)
    final_embeddings = normalized_embeddings.eval()
# Out:
# Initialized
# Average loss at step 0: 8.486676
# Nearest to during: templar, backspace, confirms, pesach, gre, sep, prohibit, resignations,
# Nearest to about: illustrates, friedmann, endpoint, elysium, nippur, annex, hen, eugene,
# Nearest to by: mpd, spared, gbp, malvinas, jagiellon, spahn, regenerated, marquess,
# Nearest to it: dddddd, ricardian, standardized, fenced, emf, nationalities, termination, gland,
# Nearest to people: pacemakers, slapping, plutonic, kapital, eapc, childbearing, bogies, koza,
# Nearest to with: penchant, limassol, kahanamoku, ire, bainbridge, snowball, overtaking, naomi,
# Nearest to there: rules, ooze, redevelopment, algorithm, fanpage, quadrilateral, cga, patrimony,
# Nearest to were: pathogen, beauties, frisia, tta, glorious, langdon, ka, falkland,
# Nearest to only: kg, limestones, pentecostal, soloists, gecko, wrecked, aphorism, dictates,
# Nearest to history: synchronization, peacefully, jerseys, paymaster, bullets, vermont, atonal, blackhawks,
# Nearest to had: cathedrals, somali, banchan, revivalist, dicke, fence, abdal, bremen,
# Nearest to five: hermetical, plagues, horrendous, hellboy, inhibition, machiavelli, luthor, intending,
# Nearest to been: section, mps, four, patrol, atacama, himmel, hearth, ulrike,
# Nearest to if: ani, lizard, invictus, rantissi, lightsaber, aforementioned, mahendra, cha,
# Nearest to four: rare, been, spectators, nonstandard, tampering, topographic, wojty, acyclic,
# Nearest to over: monatomic, landtag, carta, butcher, libby, cloaca, cordillera, massacred,
# Average loss at step 2000: 4.094720
# Average loss at step 4000: 3.558797
# Average loss at step 6000: 3.385756
# Average loss at step 8000: 3.245055
# Average loss at step 10000: 3.173574
# Nearest to during: templar, backspace, converges, at, on, after, consider, from,
# Nearest to about: hen, suevi, tailback, lavos, endpoint, remixes, winthrop, quantifier,
# Nearest to by: quaid, for, hedge, with, iain, virchow, ferris, colonisation,
# Nearest to it: he, this, there, she, which, they, muriel, bias,
# Nearest to people: battletech, herr, reeve, lycaon, erupts, children, plutonic, pounding,
# Nearest to with: between, in, nomadic, mayr, at, by, oxfordshire, for,
# Nearest to there: it, they, he, plaintiff, macarthur, slayton, still, usually,
# Nearest to were: are, was, had, have, athenian, abiathar, is, kiosk,
# Nearest to only: still, hobsbawm, limestones, usually, karzai, road, omim, hired,
# Nearest to history: distance, synchronization, rabbit, riffs, revelation, enormous, deadlines, additions,
# Nearest to had: has, have, was, were, administers, anglia, rosalyn, revisit,
# Nearest to five: six, eight, four, seven, nine, three, zero, two,
# Nearest to been: patrol, be, become, spontaneous, mps, were, prot, sooty,
# Nearest to if: ani, mussolini, though, invictus, vibrations, patient, thereabouts, lizard,
# Nearest to four: six, eight, five, three, seven, nine, two, zero,
# Nearest to over: wyclif, complexes, poinsot, osborne, crested, viscous, debut, visualized,
# Average loss at step 12000: 3.199871
# Average loss at step 14000: 3.152198
# Average loss at step 16000: 3.176389
# Average loss at step 18000: 3.125031
# Average loss at step 20000: 2.991145
# Nearest to during: after, converges, templar, at, in, on, before, localised,
# Nearest to about: hen, suevi, anions, endpoint, glycemic, dicots, nard, cruiser,
# Nearest to by: for, through, mobility, hedge, iain, quaid, nims, be,
# Nearest to it: he, she, there, this, which, they, muriel, what,
# Nearest to people: children, conses, battletech, plutonic, saddened, countries, taxable, those,
# Nearest to with: between, dishonesty, when, impetuous, by, inalienable, accepting, nomadic,
# Nearest to there: they, it, he, often, usually, which, still, mostly,
# Nearest to were: are, have, was, been, be, being, athenian, dangerously,
# Nearest to only: still, karzai, abbreviate, permittivity, topol, around, supply, hobsbawm,
# Nearest to history: distance, revelation, austrasia, unacceptable, riffs, mannheim, synchronization, autobahn,
# Nearest to had: has, have, was, revisit, began, rosalyn, newark, were,
# Nearest to five: six, four, seven, eight, three, zero, two, nine,
# Nearest to been: become, be, were, was, morphisms, ell, antagonistic, patrol,
# Nearest to if: when, though, cutlery, vibrations, before, patient, invictus, galina,
# Nearest to four: five, eight, three, six, seven, two, zero, nine,
# Nearest to over: wyclif, nearly, osborne, poinsot, holden, crested, debut, tact,
# Average loss at step 22000: 3.080605
# Average loss at step 24000: 3.037810
# Average loss at step 26000: 3.008836
# Average loss at step 28000: 3.033252
# Average loss at step 30000: 3.006678
# Nearest to during: after, under, in, before, converges, templar, at, within,
# Nearest to about: suevi, hen, glycemic, nitz, dicots, unplugged, brisance, moves,
# Nearest to by: through, privately, colonisation, against, hedge, mpd, jerzy, with,
# Nearest to it: he, she, there, this, they, not, which, alfa,
# Nearest to people: children, plutonic, men, battletech, conses, dubh, lycaon, countries,
# Nearest to with: between, inalienable, boer, marion, virchow, by, when, klimt,
# Nearest to there: they, it, he, still, often, mostly, these, she,
# Nearest to were: are, have, had, was, those, been, including, although,
# Nearest to only: still, karzai, until, zemin, amarna, permittivity, kubrick, abbreviate,
# Nearest to history: mannheim, revelation, biography, dishonesty, grammy, autobahn, story, discussion,
# Nearest to had: has, have, was, were, stumble, having, received, began,
# Nearest to five: four, six, three, eight, seven, nine, two, zero,
# Nearest to been: become, be, was, were, remained, morphisms, come, recreationally,
# Nearest to if: when, though, before, where, cutlery, although, since, vibrations,
# Nearest to four: six, five, seven, eight, three, nine, two, zero,
# Nearest to over: through, off, into, wyclif, bligh, crested, away, poinsot,
# Average loss at step 32000: 2.819022
# Average loss at step 34000: 2.952823
# Average loss at step 36000: 2.951045
# Average loss at step 38000: 2.935470
# Average loss at step 40000: 2.927746
# Nearest to during: in, after, before, under, when, within, from, despite,
# Nearest to about: suevi, otaku, dicots, hen, tambourine, discharging, interferometry, rebounding,
# Nearest to by: from, when, using, through, jerzy, after, hedge, entablature,
# Nearest to it: he, she, there, this, they, rebound, still, often,
# Nearest to people: children, men, tribes, women, jews, scholars, battletech, plutonic,
# Nearest to with: between, inalienable, when, nomadic, in, during, virchow, against,
# Nearest to there: they, he, it, she, still, sometimes, these, we,
# Nearest to were: are, was, have, had, those, being, insist, cobain,
# Nearest to only: abbreviate, still, either, hobsbawm, amarna, usually, last, leveling,
# Nearest to history: discussion, kama, statuette, story, autobahn, palazzo, romanus, dishonesty,
# Nearest to had: has, have, was, having, were, stumble, began, notwithstanding,
# Nearest to five: six, four, three, seven, eight, nine, two, zero,
# Nearest to been: become, be, remained, was, were, morphisms, recreationally, previously,
# Nearest to if: when, though, before, vibrations, cutlery, because, where, although,
# Nearest to four: five, six, eight, three, seven, nine, two, zero,
# Nearest to over: off, through, away, down, natura, into, against, attachments,
# Average loss at step 42000: 2.954413
# Average loss at step 44000: 2.954456
# Average loss at step 46000: 2.911065
# Average loss at step 48000: 2.873010
# Average loss at step 50000: 2.845698
# Nearest to during: in, after, before, despite, at, when, from, although,
# Nearest to about: suevi, dicots, over, rebounding, interferometry, roth, strip, iced,
# Nearest to by: through, against, without, virchow, mpd, privately, when, hedge,
# Nearest to it: he, she, there, this, they, alicia, which, yahweh,
# Nearest to people: children, women, men, players, those, plutonic, peoples, tribes,
# Nearest to with: between, xl, using, binomial, mayr, tripled, wrinkled, boer,
# Nearest to there: they, it, he, she, we, often, usually, these,
# Nearest to were: are, was, had, have, while, those, been, be,
# Nearest to only: rudi, still, either, tuff, batches, never, abbreviate, no,
# Nearest to history: list, kama, use, discussion, dishonesty, development, science, vocation,
# Nearest to had: has, have, were, having, was, began, stumble, ever,
# Nearest to five: seven, six, four, eight, three, nine, zero, two,
# Nearest to been: become, remained, be, previously, was, already, were, leapt,
# Nearest to if: when, though, where, before, while, since, because, vibrations,
# Nearest to four: seven, six, five, eight, three, two, nine, zero,
# Nearest to over: off, about, through, away, quake, osborne, intolerance, wyclif,
# Average loss at step 52000: 2.891366
# Average loss at step 54000: 2.860423
# Average loss at step 56000: 2.860926
# Average loss at step 58000: 2.756965
# Average loss at step 60000: 2.828829
# Nearest to during: in, after, when, within, under, despite, before, at,
# Nearest to about: suevi, dicots, discharging, over, mocks, nitz, interferometry, glycemic,
# Nearest to by: through, privately, quaid, mpd, shura, breakaway, virchow, hedge,
# Nearest to it: he, she, there, this, they, which, itself, today,
# Nearest to people: children, women, men, players, tribes, woman, peoples, plutonic,
# Nearest to with: between, xl, among, boer, oxfordshire, inalienable, lil, bahri,
# Nearest to there: they, it, she, he, we, still, often, sometimes,
# Nearest to were: are, have, was, had, those, been, be, argumentum,
# Nearest to only: either, still, both, therefore, actually, personae, not, score,
# Nearest to history: list, science, cheka, kama, theme, mystery, autobahn, statuette,
# Nearest to had: has, have, was, having, were, never, refused, notwithstanding,
# Nearest to five: seven, six, four, eight, three, zero, nine, two,
# Nearest to been: become, be, remained, was, recreationally, already, were, previously,
# Nearest to if: when, though, where, then, since, fraunhofer, although, before,
# Nearest to four: five, six, seven, three, eight, two, nine, zero,
# Nearest to over: through, off, about, between, into, within, intolerance, reconstructionism,
# Average loss at step 62000: 2.833949
# Average loss at step 64000: 2.777599
# Average loss at step 66000: 2.762563
# Average loss at step 68000: 2.715948
# Average loss at step 70000: 2.783594
# Nearest to during: after, under, in, before, despite, when, although, within,
# Nearest to about: dicots, nitz, suevi, why, that, calculating, glycemic, interferometry,
# Nearest to by: mpd, through, entablature, hedge, hoisted, virchow, when, privately,
# Nearest to it: she, he, there, this, they, what, which, alicia,
# Nearest to people: children, women, men, players, tribes, jews, woman, peoples,
# Nearest to with: between, among, xl, when, fl, against, casale, roleplay,
# Nearest to there: they, it, he, we, she, sometimes, often, said,
# Nearest to were: are, was, have, include, those, had, insist, became,
# Nearest to only: both, either, lasted, abbreviate, until, nusa, tattooed, even,
# Nearest to history: life, list, cheka, science, development, theme, story, presence,
# Nearest to had: has, have, was, having, since, stumble, were, notwithstanding,
# Nearest to five: six, seven, eight, three, four, nine, zero, two,
# Nearest to been: become, be, remained, previously, recreationally, was, grown, leapt,
# Nearest to if: when, though, before, where, since, because, fraunhofer, then,
# Nearest to four: five, three, seven, six, eight, two, nine, zero,
# Nearest to over: through, within, away, off, reconstructionism, lowball, around, intolerance,
# Average loss at step 72000: 2.796466
# Average loss at step 74000: 2.644268
# Average loss at step 76000: 2.798205
# Average loss at step 78000: 2.825623
# Average loss at step 80000: 2.782754
# Nearest to during: after, before, in, despite, when, under, within, throughout,
# Nearest to about: dicots, over, approximately, anions, around, calculating, glycemic, rebounding,
# Nearest to by: during, through, against, when, without, hedge, nims, mpd,
# Nearest to it: he, she, there, this, they, itself, we, alicia,
# Nearest to people: children, women, men, players, tribes, woman, jews, americans,
# Nearest to with: between, nomadic, xl, among, including, oxfordshire, via, pers,
# Nearest to there: they, it, he, we, she, sometimes, still, these,
# Nearest to were: are, was, have, those, had, been, include, insist,
# Nearest to only: either, until, abbreviate, legally, tattooed, rudi, taiga, tort,
# Nearest to history: list, ireland, science, auditioning, politicians, philosophy, jutland, voles,
# Nearest to had: has, have, having, was, were, merdeka, refused, tripled,
# Nearest to five: six, seven, four, eight, three, zero, nine, two,
# Nearest to been: become, be, were, remained, was, insensible, tuition, mayhew,
# Nearest to if: when, though, where, cannot, doesn, should, shortest, cutlery,
# Nearest to four: six, five, three, seven, eight, two, nine, zero,
# Nearest to over: around, off, through, down, about, nearly, corrado, resolute,
# Average loss at step 82000: 2.667483
# Average loss at step 84000: 2.774430
# Average loss at step 86000: 2.735110
# Average loss at step 88000: 2.753608
# Average loss at step 90000: 2.741377
# Nearest to during: in, before, after, under, within, at, throughout, despite,
# Nearest to about: over, around, approximately, dicots, suevi, glycemic, regarding, extends,
# Nearest to by: mpd, through, when, katie, nims, spared, including, gbp,
# Nearest to it: he, she, there, this, they, alicia, itself, yahweh,
# Nearest to people: women, children, men, players, tribes, peoples, woman, users,
# Nearest to with: between, via, inalienable, among, competent, oxfordshire, xl, evanston,
# Nearest to there: they, it, he, she, we, inevitably, sometimes, believed,
# Nearest to were: are, have, was, those, had, been, eisenman, including,
# Nearest to only: either, abbreviate, until, latter, legally, rudi, approximately, interjections,
# Nearest to history: list, ireland, northwestern, jutland, voles, period, vocation, coexisted,
# Nearest to had: has, have, having, was, were, stumble, produces, recently,
# Nearest to five: four, six, seven, eight, three, zero, nine, two,
# Nearest to been: become, be, remained, were, undergone, grown, mordant, traditionally,
# Nearest to if: when, though, where, before, vibrations, does, although, fraunhofer,
# Nearest to four: six, five, seven, eight, three, two, nine, zero,
# Nearest to over: off, about, around, down, aquariums, nearly, away, corrado,
# Average loss at step 92000: 2.679019
# Average loss at step 94000: 2.722927
# Average loss at step 96000: 2.701616
# Average loss at step 98000: 2.366113
# Average loss at step 100000: 2.402879
# Nearest to during: in, under, at, within, despite, after, before, throughout,
# Nearest to about: nitz, approximately, suevi, rebounding, regarding, exempt, interferometry, dicots,
# Nearest to by: through, when, without, privately, quaid, under, virchow, mpd,
# Nearest to it: she, he, there, this, they, alicia, what, itself,
# Nearest to people: women, children, men, players, jews, man, individuals, tribes,
# Nearest to with: between, lil, during, via, xl, among, nomadic, evanston,
# Nearest to there: they, he, she, it, sometimes, we, still, generally,
# Nearest to were: are, was, have, include, remain, had, been, those,
# Nearest to only: either, abbreviate, tattooed, legally, latter, interjections, necessarily, nusa,
# Nearest to history: list, tradition, siege, encyclopedia, period, northwestern, science, ireland,
# Nearest to had: has, have, having, was, were, never, ever, since,
# Nearest to five: seven, four, six, eight, three, nine, zero, two,
# Nearest to been: become, remained, be, were, traditionally, already, was, extraordinarily,
# Nearest to if: when, though, before, where, follows, fraunhofer, after, vibrations,
# Nearest to four: five, seven, six, eight, three, nine, zero, two,
# Nearest to over: off, around, down, across, away, about, intolerance, aquariums,
